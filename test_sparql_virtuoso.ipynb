# %% [markdown]
# # Send a SPARQL Query to Virtuoso
#
# We use `SPARQLWrapper` to send the sparql query

# %% [markdown]
# ## Generic

# %%
endpoint = "http://localhost:8890/sparql"

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
s = SPARQLWrapper(endpoint)
s.setReturnFormat(JSON)
s.setQuery("""
    SELECT * FROM <https://golemlab.eu/data> WHERE {
# ?s ?p ?o .
}
    """
)

# %%
s.queryAndConvert()
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://clscor.io/ontology/X1_Corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Non-binary Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Chapter'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Character'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Comment'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Document'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Harry Potter Corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Chapters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Comments in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Paragraphs in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Stories in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Words in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Paragraph'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Word'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Male Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Female Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Words in comments on the Harry Potter corpus'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '2'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '8'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '10'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '20'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '123'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '123000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '200000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '700000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '9000000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '2000000000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_document'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'}}]}}

# %% [markdown]
# ## With convenience classes

# %%
from sparql import DB, SparqlQuery

# %%
#setup sparql connection
virtuoso = DB(triplestore="virtuoso", protocol="http",url="localhost",port="8890")

# %%
# output the sparql endpoint
virtuoso.sparql_endpoint
# Out:
# 'http://localhost:8890/sparql'

# %%
testquery = """
    SELECT * FROM <https://golemlab.eu/data> WHERE {
# ?s ?p ?o .
}
    """
virtuoso.sparql(testquery)
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://clscor.io/ontology/X1_Corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Non-binary Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Chapter'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Character'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Comment'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Document'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Harry Potter Corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Chapters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Comments in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Paragraphs in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Stories in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Words in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Paragraph'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Word'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Male Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Female Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Words in comments on the Harry Potter corpus'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '2'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '8'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '10'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '20'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '123'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '123000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '200000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '700000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '9000000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '2000000000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_document'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'}}]}}

# %%
testquery2 = """
    SELECT * FROM <https://golemlab.eu/data> WHERE {
# ?s ?p ?o .
}
LIMIT 1
    """

# %%
virtuoso.sparql(testquery2)
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://clscor.io/ontology/X1_Corpus'}}]}}

# %% [markdown]
# ## Define a SPARQL Query as static class

# %%
class TestQuery(SparqlQuery):
    """A sample GOLEM query"""

    label = "Just everything"

    description = """
    Get everything that is in the graph
    """

    query = """
     SELECT * FROM <https://golemlab.eu/data> WHERE {
        # ?s ?p ?o .
    }
    """

# %%
MyQuery = TestQuery()

# %%
print(MyQuery.explain())
# Out:
# Just everything:
#     Get everything that is in the graph

# %%
print(MyQuery.query)
# Out:
#      SELECT * FROM <https://golemlab.eu/data> WHERE {
#         ?s ?p ?o .
#     }

# %%
MyQuery.execute(virtuoso)
# Out:
# True

# %%
MyQuery.results

# %%
MyQuery.results.dump()
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://clscor.io/ontology/X1_Corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Non-binary Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Chapter'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Character'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Comment'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Document'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Harry Potter Corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Chapters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Comments in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Paragraphs in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Stories in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Words in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Paragraph'}},
#    {'s': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'value': 'Word'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Male Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of distinct Female Characters in the Harry Potter corpus'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal',
#      'value': 'Number of Words in comments on the Harry Potter corpus'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'}},
#    {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '2'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '8'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '10'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '20'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '123'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '123000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '200000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '700000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '9000000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#      'value': '2000000000'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_character'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://golemlab.eu/ontology/unit_document'}},
#    {'s': {'type': 'uri',
#      'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#     'p': {'type': 'uri',
#      'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#     'o': {'type': 'uri',
#      'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'}}]}}

# %%
MyQuery.results.vars
# Out:
# ['s', 'p', 'o']

# %%
MyQuery.results.bindings
# Out:
# [{'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri', 'value': 'http://clscor.io/ontology/X1_Corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_character'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#  {'s': {'type': 'uri',
#    'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E85_Measurement_Unit'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#   'p': {'type': 'uri',
#    'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#   'o': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/E54_Dimension'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of distinct Characters in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of distinct Non-binary Characters in the Harry Potter corpus'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Chapter'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_character'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Character'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Comment'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Document'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Harry Potter Corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of Chapters in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of Comments in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of Paragraphs in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of Stories in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of Words in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Paragraph'}},
#  {'s': {'type': 'uri',
#    'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal', 'value': 'Word'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of distinct Male Characters in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of distinct Female Characters in the Harry Potter corpus'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#   'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#   'o': {'type': 'literal',
#    'value': 'Number of Words in comments on the Harry Potter corpus'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'}},
#  {'s': {'type': 'uri', 'value': 'http://golemlab.eu/data/potter_corpus'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P43_has_dimension'},
#   'o': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '2'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '8'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '10'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '20'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '123'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '123000'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '200000'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '700000'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '9000000'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P90_has_value'},
#   'o': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#int',
#    'value': '2000000000'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_paragraphs'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri',
#    'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Paragraph'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_chapters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_chapter'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_male_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_character'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_character'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_female_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_character'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_nonbinary_characters'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_character'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_comments'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-comments'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_comment'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_documents'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri', 'value': 'http://golemlab.eu/ontology/unit_document'}},
#  {'s': {'type': 'uri',
#    'value': 'http://golemlab.eu/data/potter_corpus/measurement/number_of_words-text'},
#   'p': {'type': 'uri',
#    'value': 'http://www.cidoc-crm.org/cidoc-crm/P91_has_unit'},
#   'o': {'type': 'uri',
#    'value': 'http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Word'}}]
